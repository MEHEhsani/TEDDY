# %% [markdown]
# ## About
# Teddy is about extracting datils of talks from www.ted.com and reperesents a list of speachs to you.
# Teddy asks you to select topic and subtitled language then provides you a list of top TED Talks regarding your choices in csv format in your selected address.

# %%
# importing Libraries
import pandas as pd


from bs4 import BeautifulSoup as bs
import requests

import re

# %% [markdown]
# ## Pilot1: Extracting 1 page/ Tag = "Goal"

# %% [markdown]
# #### For Pilot Teddy, Tag is "Goal"
# Ted Talks in Persin and English about Goal

# %%
url= "https://www.ted.com/talks?language=en&page=1&sort=newest&topics%5B%5D=goals"
page= requests.get(url)
print(page.reason)
# Out:
# OK

# %%
soup=bs(page.content, "html.parser")

s=soup.find_all('div' , {'class':"media__message"})

#presenter=p.find({"class":"h12 talk-link__speaker"})
presenter_list=[]
title_list=[]
release_list=[]
link_list=[]

for item in s: 
    d=item.text.split("\n")
    presenter=d[1]
    presenter_list.append(presenter)
    
    title=d[4]
    title_list.append(title)
    
    release=d[11]
    release_list.append(release)
    
    # getting the link    
    li= item.find('a', {"class":"ga-link"})
    lin= li.get('href')
    link_list.append(lin)
    

#print('presenter_list = ' , presenter_list,  '\n')
print('len(presenter_list) = ' , len(presenter_list),  '\n')

#print('title_list = ' , title_list, '\n')
print('len(title_list) = ' , len(title_list), '\n')

#print('release_list = ' , release_list, '\n')
print('len(release_list) = ' , len(release_list), '\n')

#print('link_list = ' , link_list)
print('en(link_list) = ' , len(link_list))
# Out:
# len(presenter_list) =  36
#
# len(title_list) =  36
#
# len(release_list) =  36
#
# en(link_list) =  36

# %% [markdown]
# ## Pilot 2: Extracting 2 pages of Tag = "Goal"

# %%
presenter_list=[]
title_list=[]
release_list=[]
link_list=[]

# url = u1 + page_number + u2
# for page 1:
# https://www.ted.com/talks?language=en&page=1&sort=newest&topics%5B%5D=goals
u1= 'https://www.ted.com/talks?language=en&page='
u2= '&sort=newest&topics%5B%5D=goals'


for p in range(1,3):
    url= u1+str(p)+u2
    page= requests.get(url)
    print(page.status_code) # print(page.reason)
    
    soup=bs(page.content, "html.parser")

    s=soup.find_all('div' , {'class':"media__message"})

    #presenter=p.find({"class":"h12 talk-link__speaker"})


    for item in s: 
        d=item.text.split("\n")
        presenter=d[1]
        presenter_list.append(presenter)
    
        title=d[4]
        title_list.append(title)
    
        release=d[11]
        release_list.append(release)
        
        li= item.find('a', {"class":"ga-link"})
        lin= li.get('href')
        lin= "https://www.ted.com"+lin
        link_list.append(lin)
        
        
    #print('presenter_list = ' , presenter_list,  '\n')
    #print('title_list = ' , title_list, '\n')
    #print('release_list = ' , release_list)
    #print('link_list = ' , link_list)
# Out:
# 200
# 200

# %%
print('len(presenter_list) = ',len(presenter_list))
print('len(title_list) = ',len(title_list))
print('len(release_list) = ',len(release_list))
print('len(link_list) = ',len(link_list))
# Out:
# len(presenter_list) =  62
# len(title_list) =  62
# len(release_list) =  62
# len(link_list) =  62

# %%
# Creating Data Frame

df_Ted = pd.DataFrame()
df_Ted['Presenter']= presenter_list
df_Ted['Title'] = title_list
df_Ted['Published in']= release_list
df_Ted['Tag'] = 'Goal'
df_Ted['Link Address']= link_list
df_Ted['Language'] = 'En'

df_Ted.head(2)
# Out:
#     Presenter                                              Title Published in  \
# 0      Cordae  How a "Hi Level" mindset helps you realize you...     Jun 2022
# 1  Bevy Smith   How to discover your authentic self — at any age     May 2022
#
#     Tag                                       Link Address Language
# 0  Goal  https://www.ted.com/talks/cordae_how_a_hi_leve...       En
# 1  Goal  https://www.ted.com/talks/bevy_smith_how_to_di...       En

# %%
df_Ted.to_csv("E:/Hamid/Data Science/Teddy.csv")

# %% [markdown]
# ## Final Product
# The topic and subtitle would be defined by user

# %%
Tag= input(print("Please import your Topic"))
Language = input(print("Please choice a language(En/Fa/Es/Ko/Fr)"))
Ad=input(print("Please import an address to Teddy store the outcome?"))

u1= 'https://www.ted.com/talks?language='+Language+'&page='
u2= '&sort=newest&topics%5B%5D='+Tag

presenter_list=[]
title_list=[]
release_list=[]
link_list=[]

for p in range(1,5):
    url= u1+str(p)+u2
    page= requests.get(url)
    #print(page.status_code) # print(page.reason)
    
    soup=bs(page.content, "html.parser")

    s=soup.find_all('div' , {'class':"media__message"})

    #presenter=p.find({"class":"h12 talk-link__speaker"})


    for item in s: 
        d=item.text.split("\n")
        presenter=d[1]
        presenter_list.append(presenter)
    
        title=d[4]
        title_list.append(title)
    
        release=d[11]
        release_list.append(release)
        
        li= item.find('a', {"class":"ga-link"})
        lin= li.get('href')
        lin= "https://www.ted.com"+lin
        link_list.append(lin)
        
        
    #print('presenter_list = ' , presenter_list,  '\n')
    #print('title_list = ' , title_list, '\n')
    #print('release_list = ' , release_list)
    #print('link_list = ' , link_list)
    
# Creating Data Frame

df_Ted = pd.DataFrame()
df_Ted['Presenter']= presenter_list
df_Ted['Title'] = title_list
df_Ted['Published in']= release_list
df_Ted['Topic'] = Tag
df_Ted['Link Address']= link_list
df_Ted['Language'] = Language

file_name = "/Teddy_"+Tag+"_"+Language+".csv"
address= Ad + file_name
df_Ted.to_csv(address)
print("Thanks for your attention :)! The {file} is creater in\n {Ad}".format(file=file_name, Ad=Ad))
print("\n Please share your exprience via following mail address: \n h.ehsani20012@gmail.com")
# Out:
# Please import your Topic
# NoneLeadership
# Please choice a language(En/Fa/Es/Ko/Fr)
# NoneEn
# Please import an address to Teddy store the outcome?
# NoneE:/Hamid/Data Science
# Thanks for your attention :)! The /Teddy_Leadership_En.csv is creater in
#  E:/Hamid/Data Science
#
#  Please share your exprience via following mail address:
#  h.ehsani20012@gmail.com

# %%
print('len(presenter_list) = ',len(presenter_list))
print('len(title_list) = ',len(title_list))
print('len(release_list) = ',len(release_list))
print('len(link_list) = ',len(link_list))
# Out:
# len(presenter_list) =  144
# len(title_list) =  144
# len(release_list) =  144
# len(link_list) =  144

# %%
df_Ted
# Out:
#                 Presenter                                              Title  \
# 0                  TED-Ed           These companies with no CEO are thriving
# 1            Sara Lomelin            Your invitation to disrupt philanthropy
# 2    Katherine Mangu-Ward  What capitalism gets right — and governments g...
# 3    Trish Millines Dziko     How schools can nurture every student's genius
# 4            Jim VandeHei                     How to write less but say more
# ..                    ...                                                ...
# 139           Elif Shafak         The revolutionary power of diverse thought
# 140   Christiane Amanpour          How to seek truth in the era of fake news
# 141   Olúfẹ́mi Táíwò  Why Africa must become a center of knowledge a...
# 142             Ray Dalio    How to build a company where the best ideas win
# 143        Jonathan Marks                              In praise of conflict
#
#     Published in       Topic  \
# 0       Sep 2022  Leadership
# 1       Sep 2022  Leadership
# 2       Sep 2022  Leadership
# 3       Jul 2022  Leadership
# 4       Jul 2022  Leadership
# ..           ...         ...
# 139     Oct 2017  Leadership
# 140     Oct 2017  Leadership
# 141     Sep 2017  Leadership
# 142     Sep 2017  Leadership
# 143     Apr 2017  Leadership
#
#                                           Link Address Language
# 0    https://www.ted.com/talks/ted_ed_these_compani...       En
# 1    https://www.ted.com/talks/sara_lomelin_your_in...       En
# 2    https://www.ted.com/talks/katherine_mangu_ward...       En
# 3    https://www.ted.com/talks/trish_millines_dziko...       En
# 4    https://www.ted.com/talks/jim_vandehei_how_to_...       En
# ..                                                 ...      ...
# 139  https://www.ted.com/talks/elif_shafak_the_revo...       En
# 140  https://www.ted.com/talks/christiane_amanpour_...       En
# 141  https://www.ted.com/talks/oluf_mi_taiwo_why_af...       En
# 142  https://www.ted.com/talks/ray_dalio_how_to_bui...       En
# 143  https://www.ted.com/talks/jonathan_marks_in_pr...       En
#
# [144 rows x 6 columns]
